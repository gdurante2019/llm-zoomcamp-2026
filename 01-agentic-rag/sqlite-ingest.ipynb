# %% [markdown]
# # Ingestion notebook
#
# We're asked to create a small notebook called sqlite-ingest.ipynb just for the ingestion portion of the persistent RAG setup.
#
# We need to install sqlitesearch if it isn't installed already.

# %%
# uv add sqlitesearch

# %% [markdown]
# First, load the data using the function from ```ingest.py```:

# %%
from ingest import load_faq_data

documents = load_faq_data()
print(f"Loaded {len(documents)} documents")
# Out:
# Loaded 1350 documents

# %% [markdown]
# Filter to just the LLM Zoomcamp documents:

# %%
docs_llm = [doc for doc in documents if doc["course"] == "llm-zoomcamp"]
print(f"LLM Zoomcamp: {len(docs_llm)} documents")
# Out:
# LLM Zoomcamp: 85 documents

# %% [markdown]
# Now create a sqlitesearch index and add documents one by one with a small delay (to simulate slow ingestion):

# %%
import time
from sqlitesearch import TextSearchIndex

index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

for doc in docs_llm:
    index.add(doc)
    print(f"""Added:  {doc["question"][:40]}...""")
    time.sleep(0.5)

index.close()
print("Done.  Index saved to faq.db")
# Out:
# Added:  I just discovered the course. Can I stil...
# Added:  Course: I have registered for the LLM Zo...
# Added:  What is the video/zoom link to the strea...
# Added:  How should I start the course and follow...
# Added:  Leaderboard: I am not on the leaderboard...
# Added:  Certificate: Can I follow the course in ...
# Added:  I missed the first homework - can I stil...
# Added:  Homework: Why does the content keep chan...
# Added:  When will the course be offered next?...
# Added:  Are there any lectures/videos? Where are...
# Added:  Where can I track the LLM Zoomcamp sylla...
# Added:  Are there live sessions or office hours ...
# Added:  Can I use Bluesky for learning in public...
# Added:  Where is the LLM Zoomcamp Telegram chann...
# Added:  Why are we not using Langchain in the co...
# Added:  OpenAI: Error when running OpenAI respon...
# Added:  OpenAI: Error: RateLimitError: Error cod...
# Added:  OpenAI: How much will I have to spend to...
# ...

# %% [markdown]
# We saw that each document was added one by one, and the index was saved to ```faq.db```.  With the index saved here, it persists across restarts.

# %%
index.close()

# %% [markdown]
# ## Querying notebook
#
# We are asked to create another notebook, this time for running queries that connect to the faq.db database.
